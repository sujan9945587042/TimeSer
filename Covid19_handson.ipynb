# %% [markdown]
# <a href="https://colab.research.google.com/github/sujan9945587042/TimeSer/blob/main/Covid19_handson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/covid_19_clean_complete (2).csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %%
df.rename(columns={
    'Province/State':'state',
    'Country/Region':'Country'
},inplace=True)

# %%
df.head()
# Out:
#   state      Country       Lat       Long        Date  Confirmed  Deaths  \
# 0   NaN  Afghanistan  33.93911  67.709953  2020-01-22          0       0
# 1   NaN      Albania  41.15330  20.168300  2020-01-22          0       0
# 2   NaN      Algeria  28.03390   1.659600  2020-01-22          0       0
# 3   NaN      Andorra  42.50630   1.521800  2020-01-22          0       0
# 4   NaN       Angola -11.20270  17.873900  2020-01-22          0       0
#
#    Recovered  Active             WHO Region
# 0          0       0  Eastern Mediterranean
# 1          0       0                 Europe
# 2          0       0                 Africa
# 3          0       0                 Europe
# 4          0       0                 Africa

# %%
df_total=df.groupby(['Date'])['Confirmed'].sum().reset_index()

# %%
df_total
# Out:
#            Date  Confirmed
# 0    2020-01-22        555
# 1    2020-01-23        654
# 2    2020-01-24        941
# 3    2020-01-25       1434
# 4    2020-01-26       2118
# ..          ...        ...
# 183  2020-07-23   15510481
# 184  2020-07-24   15791645
# 185  2020-07-25   16047190
# 186  2020-07-26   16251796
# 187  2020-07-27   16480485
#
# [188 rows x 2 columns]

# %%
df_total.plot()
# Out:
# <Axes: >

# %%
# !pip install Prophet

# %%
from prophet import Prophet

# %%
df_total.rename(columns={
                'Date':'ds',
                'Confirmed':'y'},inplace=True)

# %%
model=Prophet()

# %%
model.fit(df_total)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpz236z51g/kr1stqh9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpz236z51g/b08t1gzc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29751', 'data', 'file=/tmp/tmpz236z51g/kr1stqh9.json', 'init=/tmp/tmpz236z51g/b08t1gzc.json', 'output', 'file=/tmp/tmpz236z51g/prophet_model9bwpf9n9/prophet_model-20251007112344.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:23:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:23:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future=model.make_future_dataframe(periods=7)
forcasted_data=model.predict(future)

# %%
forcasted_data
# Out:
#             ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0   2020-01-22 -9.613281e+03 -1.214504e+05  8.164177e+04 -9.613281e+03
# 1   2020-01-23 -6.933404e+03 -1.081173e+05  1.006132e+05 -6.933404e+03
# 2   2020-01-24 -4.253528e+03 -1.025887e+05  1.179767e+05 -4.253528e+03
# 3   2020-01-25 -1.573651e+03 -9.569294e+04  1.202753e+05 -1.573651e+03
# 4   2020-01-26  1.106226e+03 -1.000858e+05  1.112954e+05  1.106226e+03
# ..         ...           ...           ...           ...           ...
# 190 2020-07-30  1.674503e+07  1.663493e+07  1.684412e+07  1.673930e+07
# 191 2020-07-31  1.694902e+07  1.684426e+07  1.706796e+07  1.693762e+07
# 192 2020-08-01  1.715301e+07  1.705374e+07  1.727777e+07  1.713549e+07
# 193 2020-08-02  1.735700e+07  1.725398e+07  1.747724e+07  1.732945e+07
# 194 2020-08-03  1.756099e+07  1.744791e+07  1.767828e+07  1.752438e+07
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# ...

# %%
model.plot(forcasted_data)
plt.show()
